# %%
from ultralytics import YOLO
import torch

print(torch.cuda.is_available())

model = YOLO("/home/ajeet/Downloads/v8_nano_production.pt", verbose=True).to("cuda")
# Out:
# WARNING ⚠️ Python>=3.10 is required, but Python==3.8.10 is currently installed
# True

# %%
model.val(data="/home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/yolo_retrain_yaml.yaml", imgsz=640, batch=16)
# Out:
# val: Scanning /home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/val/labels...:   0%|          | 0/2077 [00:00<?, ?it/s]
# val: Scanning /home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/val/labels... 2077 images, 15 backgrounds, 0 corrupt: 100%|██████████| 2077/2077 [00:00<00:00, 2400.61it/s]
# val: New cache created: /home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/val/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 130/130 [00:15<00:00,  8.52it/s]
#                    all       2077       5267      0.963       0.92      0.988       0.92
#                 person       2033       2113       0.99      0.731      0.985      0.955
#                   face       1777       1844      0.981      0.989      0.993      0.906
#                 mobile        484        484      0.975      0.982       0.99       0.93
# ...

# %%
# for param in model.parameters():
#     param.requires_grad = True


# trainable_params = 0
# non_trainable_params = 0

# for param in model.parameters():
#     if param.requires_grad:
#         trainable_params += param.numel() 
#     else:
#         non_trainable_params += param.numel()

# print(f"Trainable parameters: {trainable_params}")
# print(f"Non-trainable parameters: {non_trainable_params}")


# for name, param in model.model.named_parameters():
#     print(f"{name}: {param.requires_grad}")

# %%
model.info(detailed=True)
# Out:
# layer                                     name  gradient   parameters                shape         mu      sigma
#     0                      model.0.conv.weight     False          432        [16, 3, 3, 3]    -0.0929       4.18 torch.float32
#     1                        model.0.conv.bias     False           16                 [16]       1.51       4.21 torch.float32
#     2                      model.1.conv.weight     False         4608       [32, 16, 3, 3]  -1.43e-05      0.299 torch.float32
#     3                        model.1.conv.bias     False           32                 [32]       2.07       5.71 torch.float32
#     4                  model.2.cv1.conv.weight     False         1024       [32, 32, 1, 1]    -0.0131      0.131 torch.float32
#     5                    model.2.cv1.conv.bias     False           32                 [32]       1.89       2.85 torch.float32
# ...

# %%
results = model.train(data="/home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/yolo_retrain_yaml.yaml", epochs=10, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.35 available 😃 Update with 'pip install -U ultralytics'
# ...

# %%
print("Class indices with average precision:", results.ap_class_index)
print("Average precision for all classes:", results.box.all_ap)
print("Average precision:", results.box.ap)
print("Average precision at IoU=0.50:", results.box.ap50)
print("Class indices for average precision:", results.box.ap_class_index)
print("Class-specific results:", results.box.class_result)
print("F1 score:", results.box.f1)
print("F1 score curve:", results.box.f1_curve)
print("Overall fitness score:", results.box.fitness)
print("Mean average precision:", results.box.map)
print("Mean average precision at IoU=0.50:", results.box.map50)
print("Mean average precision at IoU=0.75:", results.box.map75)
print("Mean average precision for different IoU thresholds:", results.box.maps)
print("Mean results for different metrics:", results.box.mean_results)
print("Mean precision:", results.box.mp)
print("Mean recall:", results.box.mr)
print("Precision:", results.box.p)
print("Precision curve:", results.box.p_curve)
print("Precision values:", results.box.prec_values)
print("Specific precision metrics:", results.box.px)
print("Recall:", results.box.r)
print("Recall curve:", results.box.r_curve)
# Out:
# Class indices with average precision: [0 1]
# Average precision for all classes: [[      0.745       0.745       0.745       0.745       0.745       0.745       0.745       0.745       0.745     0.12462]
#  [    0.49898     0.49898     0.49898           0           0           0           0           0           0           0]]
# Average precision: [    0.68296      0.1497]
# Average precision at IoU=0.50: [      0.745     0.49898]
# Class indices for average precision: [0 1]
# Class-specific results: <bound method Metric.class_result of ultralytics.utils.metrics.Metric object with attributes:
#
# all_ap: array([[      0.745,       0.745,       0.745,       0.745,       0.745,       0.745,       0.745,       0.745,       0.745,     0.12462],
#        [    0.49898,     0.49898,     0.49898,           0,           0,           0,           0,           0,           0,           0]])
# ap: array([    0.68296,      0.1497])
# ap50: array([      0.745,     0.49898])
# ...

# %%
# from torchsummary import summary

# summary(model, input_size=(3, 640, 640))

# %%
model.info(detailed=True)
# Out:
# layer                                     name  gradient   parameters                shape         mu      sigma
#     0                      model.0.conv.weight     False          864        [32, 3, 3, 3]  -0.000651      0.128 torch.float32
#     1                        model.0.bn.weight     False           32                 [32]       4.12       1.05 torch.float32
#     2                          model.0.bn.bias     False           32                 [32]      0.291       2.96 torch.float32
#     3                      model.1.conv.weight     False        18432       [64, 32, 3, 3]  -0.000493     0.0314 torch.float32
#     4                        model.1.bn.weight     False           64                 [64]        3.6      0.771 torch.float32
#     5                          model.1.bn.bias     False           64                 [64]      0.704       1.37 torch.float32
# ...

# %%
import yaml

with open('/home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/yolo_retrain_yaml.yaml', 'r') as f:
    hyperparams = yaml.safe_load(f)

# %%
hyperparams
# Out:
# {'train': '/home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/train/images',
#  'val': '/home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/train/images',
#  'test': '/home/ajeet/codework/datasets/yolo_retrain/test_fine_tunedataset/test/images',
#  'hsv_h': 0.015,
#  'hsv_s': 0.7,
#  'hsv_v': 0.4,
#  'translate': 0.1,
#  'scale': 0.5,
#  'flipud': 0.0,
#  'fliplr': 0.5,
#  'nc': 4,
#  'names': {0: 'PERSON', 1: 'FACE', 2: 'MOBILE', 3: 'HAND'}}

# %%
import yaml
from ultralytics import YOLO

# Load the YAML file
with open('defaults.yaml', 'r') as f:
    hyperparams = yaml.safe_load(f)

# Load your model
model = YOLO('/home/haige/yolo_0408/ultralytics-main/ultralytics/yolov8m.pt', task='detect')
model.info()

# Train using the hyperparameters from the YAML file
results = model.train(data='/home/haige/yolo_0408/ultralytics-main/ultralytics/pzwrj.yaml', **hyperparams)
